# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from algos.classical import *
from algos.advanced import *
import matplotlib.pyplot as plt
import scipy.io as sio    
import glob
from statistics import mean, stdev, variance
import time
import scipy
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif

# %%
Classical_Functions = [nmieo]

# %%
for func in Classical_Functions:
    func_name = func.__name__.upper()
    
    files = glob.glob("datasets/*.mat")
    files = list(files)
    files.sort()
    
    for file in files:
        
        dataset_name = file[9:-4].upper()
        print(dataset_name)
        data  = sio.loadmat(file)
        X  = data['X']
        if type(X) is scipy.sparse.csc.csc_matrix:
            X = X.toarray()
        else:
            X = np.asarray(X)
        y = np.asarray(data['Y'])
        variables = []
        for col in range(X.shape[1]):
            variables.append({'col' : col, 'var' : np.var(X[:, col])})
        
        sortedvars = sorted(variables, key=lambda d: d['var'], reverse= True) 
        
        X_new = np.empty((X.shape[0], 0))
        for i in range(min(X.shape[1], 5000)):
            X_new = np.concatenate((X_new, X[:, sortedvars[i]['col']].reshape(-1, 1)), 1)
        
        X = X_new
        X_new = None
        variables = None
        sortedvars = None
        
        print('Low Variance Features removed')
        X = StandardScaler().fit_transform(X)
        print('Standardized')
        
        mf = SelectKBest(mutual_info_classif, k=100)
        X = mf.fit_transform(X, y.reshape(-1))
        print('Mutual Information Filter Applied')
    
        runs = 10
        Accuracy_Score = []
        Fitness_Score = []
        Selected_Features = []
        Convergence_curve = []
        Time = []
        Scores = [Accuracy_Score, Selected_Features, Time, Fitness_Score]
    
        k    = 5     # k-value in KNN
        N    = 20    # number of particles
        T    = 100   # maximum number of iterations

        opts = {'k':k, 'N':N, 'T':T}

        for i in range(runs):
            start_time = time.time()
            fmdl = func(X, y, opts)
            time_taken = time.time() - start_time
            
            Acc       = fmdl['acc']
            num_feat = float(fmdl['num_feat'])
            curve   = fmdl['c']
            curve   = curve.reshape(np.size(curve,1))
            fitness = fmdl['fitness']

            print(f' Run {i+1}')
            print("Accuracy:", 100 * Acc)
            print("Feature Size:", num_feat)
            print("Fitness:", fitness)
            print("Time:", time_taken)
            print('------------------------------------')

            Accuracy_Score.append(Acc)
            Fitness_Score.append(fitness)
            Selected_Features.append(num_feat)
            if i == 0 or curve[-1] < Convergence_curve[-1]:
                Convergence_curve = curve
            Time.append(time_taken)

        print(f'Function : {func_name} Dataset : {dataset_name}')
        print("Accuracy:", 100*mean(Accuracy_Score))
        print("Feature Size:", mean(Selected_Features))
        print("Fitness:", mean(Fitness_Score))
        print("Time:", mean(Time))

        x = np.arange(0, opts['T'], 1.0) + 1.0
        fig, ax = plt.subplots()
        ax.plot(x, Convergence_curve, 'o-')
        ax.set_xlabel('Number of Iterations')
        ax.set_ylabel('Fitness')
        ax.set_title(func_name)
        ax.grid()
        plt.show()
# Out:
# 11_TUMORS
# Low Variance Features removed
# Standardized
# Mutual Information Filter Applied
#  Run 1
# Accuracy: 97.22222222222221
# Feature Size: 31.0
# Fitness: 0.030600000000000016
# Time: 47.99458622932434
# ------------------------------------
# Function : NMIEO Dataset : 11_TUMORS
# Accuracy: 97.22222222222221
# Feature Size: 31.0
# Fitness: 0.030600000000000016
# Time: 47.99458622932434
# 9_TUMORS
# Low Variance Features removed
# Standardized
# Mutual Information Filter Applied
#  Run 1
# Accuracy: 86.66666666666667
# Feature Size: 35.0
# Fitness: 0.13549999999999998
# Time: 34.97228002548218
# ------------------------------------
# Function : NMIEO Dataset : 9_TUMORS
# Accuracy: 86.66666666666667
# Feature Size: 35.0
# Fitness: 0.13549999999999998
# Time: 34.97228002548218
# CLL_SUB_111
# Low Variance Features removed
# Standardized
# Mutual Information Filter Applied
#  Run 1
# Accuracy: 92.5
# Feature Size: 27.0
# Fitness: 0.07695
# Time: 41.19523286819458
# ------------------------------------
# Function : NMIEO Dataset : CLL_SUB_111
# Accuracy: 92.5
# Feature Size: 27.0
# Fitness: 0.07695
# Time: 41.19523286819458
# GLA-BRA-180
# Low Variance Features removed
# Standardized
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-91dbe81320ce> in <module>
#      37
#      38         mf = SelectKBest(mutual_info_classif, k=100)
# ---> 39         X = mf.fit_transform(X, y.reshape(-1))
#      40         print('Mutual Information Filter Applied')
#      41
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
# --> 693             return self.fit(X, y, **fit_params).transform(X)
#     694
#     695
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     351
#     352         self._check_params(X, y)
# --> 353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
#     355             self.scores_, self.pvalues_ = score_func_ret
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     445     """
#     446     check_classification_targets(y)
# --> 447     return _estimate_mi(X, y, discrete_features, True, n_neighbors,
#     448                         copy, random_state)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     286         y += 1e-10 * np.maximum(1, np.mean(np.abs(y))) * rng.randn(n_samples)
#     287
# --> 288     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
#     289           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     290
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_mutual_info.py in <listcomp>(.0)
#     286         y += 1e-10 * np.maximum(1, np.mean(np.abs(y))) * rng.randn(n_samples)
#     287
# --> 288     mi = [_compute_mi(x, y, discrete_feature, discrete_target, n_neighbors) for
#     289           x, discrete_feature in zip(_iterate_columns(X), discrete_mask)]
#     290
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     159         return _compute_mi_cd(y, x, n_neighbors)
#     160     elif not x_discrete and y_discrete:
# --> 161         return _compute_mi_cd(x, y, n_neighbors)
#     162     else:
#     163         return _compute_mi_cc(x, y, n_neighbors)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_mutual_info.py in _compute_mi_cd(c, d, n_neighbors)
#     123             nn.set_params(n_neighbors=k)
#     124             nn.fit(c[mask])
# --> 125             r = nn.kneighbors()[0]
#     126             radius[mask] = np.nextafter(r[:, -1], 0)
#     127             k_all[mask] = k
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     660                 delayed_query = delayed(_tree_query_parallel_helper)
#     661                 parallel_kwargs = {"prefer": "threads"}
# --> 662             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#     663                 delayed_query(
#     664                     self._tree, X[s], n_neighbors, return_distance)
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\AppData\Roaming\Python\Python38\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     490     under PyPy.
#     491     """
# --> 492     return tree.query(*args, **kwargs)
#     493
#     494
#
# KeyboardInterrupt:
